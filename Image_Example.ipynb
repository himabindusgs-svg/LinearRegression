# %% [markdown]
# <a href="https://colab.research.google.com/github/himabindusgs-svg/LinearRegression/blob/main/Image_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scenario: Converting an Image to Grayscale
# 🎯 Context
# A student wants to learn how to use OpenCV for basic image manipulation. The simplest starting point is to load a color image and convert it into grayscale.
# 📂 Dataset
# Any sample image file (e.g., "sample.jpg") placed in the working directory.


import cv2
import matplotlib.pyplot as plt

from google.colab import files


#uploaded = files.upload()


image = cv2.imread("mountain.jpg")


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)

plt.title("Scenary")

plt.axis("off")

plt.show()




gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


plt.imshow(gray, cmap='gray')

plt.title("Grayscale Image")

plt.axis("off")
plt.show()


resized = cv2.resize(image_rgb, (200, 200))
plt.imshow(resized)

plt.title("Resized mountain")

plt.axis("off")

plt.show()


cropped_img = image[50:150, 100:150]
plt.imshow(cropped_img)

plt.title("Cropped mountain")

plt.axis("off")

plt.show()
