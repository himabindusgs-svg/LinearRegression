# %% [markdown]
# <a href="https://colab.research.google.com/github/himabindusgs-svg/LinearRegression/blob/main/StopWords_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')

text = "Today is Friday. I love AI class. This is an AI class"

words = word_tokenize(text)

stop_words = set(stopwords.words('english'))

filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("Hima Bindu")
print(filtered_words)
# Out:
# Hima Bindu
# ['Today', 'Friday', '.', 'love', 'AI', 'class', '.', 'AI', 'class']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
