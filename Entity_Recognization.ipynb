# %% [markdown]
# <a href="https://colab.research.google.com/github/himabindusgs-svg/LinearRegression/blob/main/Entity_Recognization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Pierce Brosman lives in NewYork"

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Pierce Brosman PERSON
# NewYork ORG
